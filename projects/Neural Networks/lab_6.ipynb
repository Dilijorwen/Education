# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error
import lightgbm as lgb
from sklearn.preprocessing import LabelEncoder
from lightgbm import early_stopping, log_evaluation

# %%
TRAIN_FILE = "datasets/superstore_train.csv"
TEST_FILE = "datasets/superstore_test.csv"
OUTPUT_FILE = "datasets/test_result.csv"
RANDOM_STATE = 2004
NFOLDS = 20

# %%
train = pd.read_csv(TRAIN_FILE, parse_dates=["Order Date", "Ship Date"], dayfirst=False)
test = pd.read_csv(TEST_FILE, parse_dates=["Order Date", "Ship Date"], dayfirst=False)

# %%
train
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 7995    7996  US-2015-165743 2015-11-20 2015-11-23    Second Class
# 7996    7997  US-2017-105998 2017-11-03 2017-11-05     First Class
# 7997    7998  US-2017-105998 2017-11-03 2017-11-05     First Class
# 7998    7999  US-2014-148194 2014-05-04 2014-05-07     First Class
# 7999    8000  US-2014-148194 2014-05-04 2014-05-07     First Class
#
#      Customer ID    Customer Name      Segment        Country  \
# 0       CG-12520      Claire Gute     Consumer  United States
# 1       CG-12520      Claire Gute     Consumer  United States
# 2       DV-13045  Darrin Van Huff    Corporate  United States
# 3       SO-20335   Sean O'Donnell     Consumer  United States
# 4       SO-20335   Sean O'Donnell     Consumer  United States
# ...          ...              ...          ...            ...
# 7995    MM-18055   Michelle Moray     Consumer  United States
# 7996    CR-12580    Clay Rozendal  Home Office  United States
# 7997    CR-12580    Clay Rozendal  Home Office  United States
# 7998    BS-11365     Bill Shonely    Corporate  United States
# 7999    BS-11365     Bill Shonely    Corporate  United States
#
#                  City  ... Postal Code  Region       Product ID  \
# 0           Henderson  ...       42420   South  FUR-BO-10001798
# 1           Henderson  ...       42420   South  FUR-CH-10000454
# 2         Los Angeles  ...       90036    West  OFF-LA-10000240
# 3     Fort Lauderdale  ...       33311   South  FUR-TA-10000577
# 4     Fort Lauderdale  ...       33311   South  OFF-ST-10000760
# ...               ...  ...         ...     ...              ...
# 7995           Aurora  ...       80013    West  OFF-BI-10001758
# 7996        San Diego  ...       92037    West  TEC-AC-10004469
# 7997        San Diego  ...       92037    West  FUR-TA-10001095
# 7998          Seattle  ...       98105    West  FUR-FU-10001852
# 7999          Seattle  ...       98105    West  OFF-AP-10000696
#
#              Category Sub-Category  \
# 0           Furniture    Bookcases
# 1           Furniture       Chairs
# 2     Office Supplies       Labels
# 3           Furniture       Tables
# 4     Office Supplies      Storage
# ...               ...          ...
# 7995  Office Supplies      Binders
# 7996       Technology  Accessories
# 7997        Furniture       Tables
# 7998        Furniture  Furnishings
# 7999  Office Supplies   Appliances
#
#                                            Product Name      Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase   261.9600         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...   731.9400         3
# 2     Self-Adhesive Address Labels for Typewriters b...    14.6200         2
# 3         Bretford CR4500 Series Slim Rectangular Table   957.5775         5
# 4                        Eldon Fold 'N Roll Cart System    22.3680         2
# ...                                                 ...        ...       ...
# 7995  Wilson Jones 14 Line Acrylic Coated Pressboard...     9.6120         6
# 7996                     Microsoft Sculpt Comfort Mouse   199.7500         5
# 7997                 Chromcraft Round Conference Tables  1673.1840        12
# 7998  Eldon Regeneration Recycled Desk Accessories, ...    12.1800         7
# 7999                                Holmes Odor Grabber    57.6800         4
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 7995      0.70   -7.3692
# 7996      0.00   87.8900
# 7997      0.20   20.9148
# 7998      0.00    3.8976
# 7999      0.00   19.0344
#
# [8000 rows x 21 columns]

# %%
test
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0       8002  CA-2015-110870 2015-12-12 2015-12-15     First Class
# 1       8003  CA-2015-110870 2015-12-12 2015-12-15     First Class
# 2       8004  CA-2014-143210 2014-12-01 2014-12-03     First Class
# 3       8005  CA-2014-143210 2014-12-01 2014-12-03     First Class
# 4       8006  CA-2014-143210 2014-12-01 2014-12-03     First Class
# ...      ...             ...        ...        ...             ...
# 1988    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 1989    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 1990    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 1991    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 1992    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name   Segment        Country         City  \
# 0       KD-16270     Karen Daniels  Consumer  United States  Los Angeles
# 1       KD-16270     Karen Daniels  Consumer  United States  Los Angeles
# 2       AA-10645     Anna Andreadi  Consumer  United States       Lowell
# 3       AA-10645     Anna Andreadi  Consumer  United States       Lowell
# 4       AA-10645     Anna Andreadi  Consumer  United States       Lowell
# ...          ...               ...       ...            ...          ...
# 1988    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami
# 1989    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa
# 1990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa
# 1991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa
# 1992    CC-12220      Chris Cortes  Consumer  United States  Westminster
#
#               State  Postal Code Region       Product ID         Category  \
# 0        California        90032   West  TEC-AC-10002926       Technology
# 1        California        90032   West  OFF-SU-10001225  Office Supplies
# 2     Massachusetts         1852   East  TEC-PH-10004434       Technology
# 3     Massachusetts         1852   East  FUR-FU-10003878        Furniture
# 4     Massachusetts         1852   East  FUR-FU-10002268        Furniture
# ...             ...          ...    ...              ...              ...
# 1988        Florida        33180  South  FUR-FU-10001889        Furniture
# 1989     California        92627   West  FUR-FU-10000747        Furniture
# 1990     California        92627   West  TEC-PH-10003645       Technology
# 1991     California        92627   West  OFF-PA-10004041  Office Supplies
# 1992     California        92683   West  OFF-AP-10002684  Office Supplies
#
#      Sub-Category                                       Product Name    Sales  \
# 0     Accessories              Logitech Wireless Marathon Mouse M705  299.940
# 1        Supplies                                     Staple remover   25.760
# 2          Phones        Cisco IP Phone 7961G VoIP phone - Dark gray  271.900
# 3     Furnishings                 Linden 10" Round Wall Clock, Black   45.840
# 4     Furnishings                              Ultra Door Push Plate    9.820
# ...           ...                                                ...      ...
# 1988  Furnishings                             Ultra Door Pull Handle   25.248
# 1989  Furnishings  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.960
# 1990       Phones                              Aastra 57i VoIP phone  258.576
# 1991        Paper  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.600
# 1992   Appliances  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.160
#
#       Quantity  Discount
# 0            6       0.0
# 1            7       0.0
# 2            2       0.0
# 3            3       0.0
# 4            2       0.0
# ...        ...       ...
# 1988         3       0.2
# 1989         2       0.0
# 1990         2       0.2
# 1991         4       0.0
# 1992         2       0.0
#
# [1993 rows x 20 columns]

# %%
test_row_ids = test["Row ID"].values

# %%
train.columns = train.columns.str.strip()
test.columns = test.columns.str.strip()

# %%
for df in [train, test]:
    str_cols = df.select_dtypes(include='object').columns
    for c in str_cols:
        df[c] = df[c].astype(str).str.strip()

# %%
def add_date_features(df):
    df["order_year"] = df["Order Date"].dt.year
    df["order_month"] = df["Order Date"].dt.month
    df["order_day"] = df["Order Date"].dt.day
    df["order_weekofyear"] = df["Order Date"].dt.isocalendar().week.astype(int)
    df["order_dayofweek"] = df["Order Date"].dt.dayofweek
    df["order_dayofyear"] = df["Order Date"].dt.dayofyear
    df["ship_lead_days"] = (df["Ship Date"] - df["Order Date"]).dt.days
    return df

# %%
train = add_date_features(train)
test = add_date_features(test)

# %%
money_cols = ["Sales", "unit_price"]
train["unit_price"] = train["Sales"] / train["Quantity"].replace({0: np.nan})
test["unit_price"] = test["Sales"] / test["Quantity"].replace({0: np.nan})
for col in money_cols + ["unit_price"]:
    train[col] = np.log1p(train[col].fillna(0))
    test[col] = np.log1p(test[col].fillna(0))

# %%
prod_stats = train.groupby("Product ID")["Profit"].agg([
    ("prod_profit_mean", "mean"),
    ("prod_profit_median", "median"),
    ("prod_profit_std", "std"),
    ("prod_profit_count", "count")
]).reset_index()

# %%
state_stats = train.groupby("State")["Profit"].agg([
    ("state_profit_mean", "mean"),
    ("state_profit_median", "median"),
    ("state_profit_std", "std"),
    ("state_profit_count", "count")
]).reset_index()

# %%
cat_stats = train.groupby(["Category", "Sub-Category"])["Profit"].agg([
    ("cat_sub_profit_mean", "mean"),
    ("cat_sub_profit_count", "count")
]).reset_index()

# %%
cust_stats = train.groupby("Customer ID")["Profit"].agg([
    ("cust_profit_mean", "mean"),
    ("cust_profit_count", "count")
]).reset_index()

# %%
daily_profit = train.groupby(train["Order Date"].dt.date)["Profit"].agg(["mean", "sum", "count"]).reset_index()
daily_profit.columns = ["order_date_only", "daily_profit_mean", "daily_profit_sum", "daily_profit_count"]
daily_profit["order_date_only"] = pd.to_datetime(daily_profit["order_date_only"])

# %%
def merge_aggregates(df):
    df = df.merge(prod_stats, on="Product ID", how="left")
    df = df.merge(state_stats, on="State", how="left")
    df = df.merge(cat_stats, on=["Category", "Sub-Category"], how="left")
    df = df.merge(cust_stats, on="Customer ID", how="left")
    df["order_date_only"] = df["Order Date"].dt.normalize()
    df = df.merge(daily_profit, left_on="order_date_only", right_on="order_date_only", how="left")
    df.drop(columns=["order_date_only"], inplace=True)
    return df

# %%
train = merge_aggregates(train)
test = merge_aggregates(test)

# %%
global_mean = train["Profit"].mean()
global_std = train["Profit"].std()
fillna_map = {
    "prod_profit_mean": global_mean,
    "prod_profit_median": global_mean,
    "prod_profit_std": global_std,
    "prod_profit_count": 0,
    "state_profit_mean": global_mean,
    "state_profit_median": global_mean,
    "state_profit_std": global_std,
    "state_profit_count": 0,
    "cat_sub_profit_mean": global_mean,
    "cat_sub_profit_count": 0,
    "cust_profit_mean": global_mean,
    "cust_profit_count": 0,
    "daily_profit_mean": global_mean,
    "daily_profit_sum": 0,
    "daily_profit_count": 0
}

# %%
train.fillna(value=fillna_map, inplace=True)
test.fillna(value=fillna_map, inplace=True)

# %%
cat_features = ["Ship Mode", "Segment", "Country", "City", "State", "Region",
                "Category", "Sub-Category", "Product ID", "Customer ID"]

# %%
for col in cat_features:
    le = LabelEncoder()
    combined = pd.concat([train[col], test[col]]).astype(str)
    le.fit(combined)
    train[col + "_enc"] = le.transform(train[col].astype(str))
    test[col + "_enc"] = le.transform(test[col].astype(str))

# %%
target = "Profit"

numeric_cols = ["Sales", "Quantity", "Discount", "unit_price",
                "order_year", "order_month", "order_day", "order_weekofyear",
                "order_dayofweek", "order_dayofyear", "ship_lead_days"]
aggregate_cols = [
    "prod_profit_mean", "prod_profit_median", "prod_profit_std", "prod_profit_count",
    "state_profit_mean", "state_profit_median", "state_profit_std", "state_profit_count",
    "cat_sub_profit_mean", "cat_sub_profit_count",
    "cust_profit_mean", "cust_profit_count",
    "daily_profit_mean", "daily_profit_sum", "daily_profit_count"
]

# %%
encoded_cols = [c + "_enc" for c in cat_features]

features = numeric_cols + aggregate_cols + encoded_cols
features = [f for f in features if f in train.columns]

# %%
X = train[features]
y = np.log1p(train[target].fillna(0))

X_test = test[features]
# Out:
# /Users/daniil/.pyenv/versions/3.11.11/envs/ml-env/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
params = {
    "objective": "regression",
    "metric": "rmse",
    "verbosity": -1,
    "boosting_type": "gbdt",
    "learning_rate": 0.05,
    "num_leaves": 31,
    "feature_fraction": 0.8,
    "bagging_fraction": 0.8,
    "bagging_freq": 5,
    "seed": RANDOM_STATE,
    "lambda_l1": 0.1,
    "lambda_l2": 0.1
}

# %%
tscv = TimeSeriesSplit(n_splits=NFOLDS)
oof = np.zeros(len(X))
preds = np.zeros(len(X_test))
models = []

# %%
for fold, (train_idx, val_idx) in enumerate(tscv.split(X), 1):
    X_tr, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_tr, y_val = y.iloc[train_idx], y.iloc[val_idx]

    train_data = lgb.Dataset(X_tr, label=y_tr)
    val_data = lgb.Dataset(X_val, label=y_val, reference=train_data)

    model = lgb.train(
        params,
        train_data,
        num_boost_round=5000,
        valid_sets=[train_data, val_data],
        callbacks=[early_stopping(stopping_rounds=100),
                   log_evaluation(period=100)]
    )

    oof[val_idx] = np.expm1(model.predict(X_val, num_iteration=model.best_iteration))
    preds += np.expm1(model.predict(X_test, num_iteration=model.best_iteration)) / NFOLDS
# Out:
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.365088	valid_1's rmse: 0.656726
# [200]	training's rmse: 0.246096	valid_1's rmse: 0.641789
# [300]	training's rmse: 0.176295	valid_1's rmse: 0.640028
# [400]	training's rmse: 0.13242	valid_1's rmse: 0.641015
# Early stopping, best iteration is:
# [366]	training's rmse: 0.145328	valid_1's rmse: 0.636013
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.315493	valid_1's rmse: 0.575776
# [200]	training's rmse: 0.206973	valid_1's rmse: 0.553903
# [300]	training's rmse: 0.147613	valid_1's rmse: 0.55026
# [400]	training's rmse: 0.109658	valid_1's rmse: 0.547815
# [500]	training's rmse: 0.0859914	valid_1's rmse: 0.549679
# Early stopping, best iteration is:
# [400]	training's rmse: 0.109658	valid_1's rmse: 0.547815
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.300957	valid_1's rmse: 0.586886
# [200]	training's rmse: 0.190181	valid_1's rmse: 0.578768
# [300]	training's rmse: 0.128938	valid_1's rmse: 0.578892
# Early stopping, best iteration is:
# [230]	training's rmse: 0.167684	valid_1's rmse: 0.575357
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.300111	valid_1's rmse: 0.619204
# [200]	training's rmse: 0.191355	valid_1's rmse: 0.614036
# [300]	training's rmse: 0.129986	valid_1's rmse: 0.610911
# [400]	training's rmse: 0.0940338	valid_1's rmse: 0.609449
# Early stopping, best iteration is:
# [390]	training's rmse: 0.0968519	valid_1's rmse: 0.609161
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.315615	valid_1's rmse: 0.461267
# [200]	training's rmse: 0.206388	valid_1's rmse: 0.444603
# [300]	training's rmse: 0.147986	valid_1's rmse: 0.431765
# [400]	training's rmse: 0.112678	valid_1's rmse: 0.428854
# [500]	training's rmse: 0.0892837	valid_1's rmse: 0.427066
# [600]	training's rmse: 0.0726163	valid_1's rmse: 0.428054
# Early stopping, best iteration is:
# [505]	training's rmse: 0.0885464	valid_1's rmse: 0.426558
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.308608	valid_1's rmse: 0.491817
# [200]	training's rmse: 0.210321	valid_1's rmse: 0.484235
# [300]	training's rmse: 0.15631	valid_1's rmse: 0.483553
# [400]	training's rmse: 0.122412	valid_1's rmse: 0.483
# Early stopping, best iteration is:
# [322]	training's rmse: 0.1475	valid_1's rmse: 0.481609
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.316345	valid_1's rmse: 0.522425
# [200]	training's rmse: 0.216065	valid_1's rmse: 0.515707
# Early stopping, best iteration is:
# [156]	training's rmse: 0.250984	valid_1's rmse: 0.512757
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.3225	valid_1's rmse: 0.439712
# [200]	training's rmse: 0.222343	valid_1's rmse: 0.427585
# [300]	training's rmse: 0.168208	valid_1's rmse: 0.431852
# Early stopping, best iteration is:
# [204]	training's rmse: 0.21943	valid_1's rmse: 0.426697
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.32688	valid_1's rmse: 0.421127
# [200]	training's rmse: 0.232212	valid_1's rmse: 0.408396
# [300]	training's rmse: 0.177665	valid_1's rmse: 0.409139
# Early stopping, best iteration is:
# [215]	training's rmse: 0.221418	valid_1's rmse: 0.407722
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.322834	valid_1's rmse: 0.443519
# [200]	training's rmse: 0.23327	valid_1's rmse: 0.424289
# [300]	training's rmse: 0.18244	valid_1's rmse: 0.423326
# [400]	training's rmse: 0.148229	valid_1's rmse: 0.422906
# Early stopping, best iteration is:
# [377]	training's rmse: 0.155185	valid_1's rmse: 0.421455
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.326405	valid_1's rmse: 0.39796
# [200]	training's rmse: 0.23719	valid_1's rmse: 0.379823
# [300]	training's rmse: 0.186006	valid_1's rmse: 0.376156
# [400]	training's rmse: 0.152191	valid_1's rmse: 0.37053
# [500]	training's rmse: 0.125956	valid_1's rmse: 0.366983
# [600]	training's rmse: 0.105968	valid_1's rmse: 0.366075
# [700]	training's rmse: 0.091161	valid_1's rmse: 0.364701
# [800]	training's rmse: 0.0793099	valid_1's rmse: 0.36326
# [900]	training's rmse: 0.0690842	valid_1's rmse: 0.362752
# [1000]	training's rmse: 0.0607923	valid_1's rmse: 0.362604
# [1100]	training's rmse: 0.0540481	valid_1's rmse: 0.362575
# Early stopping, best iteration is:
# [1081]	training's rmse: 0.0553349	valid_1's rmse: 0.362278
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.323967	valid_1's rmse: 0.428475
# [200]	training's rmse: 0.23914	valid_1's rmse: 0.410634
# [300]	training's rmse: 0.190254	valid_1's rmse: 0.401657
# [400]	training's rmse: 0.156439	valid_1's rmse: 0.394145
# [500]	training's rmse: 0.130706	valid_1's rmse: 0.392169
# [600]	training's rmse: 0.110762	valid_1's rmse: 0.391665
# [700]	training's rmse: 0.0956378	valid_1's rmse: 0.391648
# [800]	training's rmse: 0.0832948	valid_1's rmse: 0.390036
# [900]	training's rmse: 0.072763	valid_1's rmse: 0.38977
# [1000]	training's rmse: 0.0640528	valid_1's rmse: 0.388919
# Early stopping, best iteration is:
# [974]	training's rmse: 0.0661049	valid_1's rmse: 0.388056
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.323106	valid_1's rmse: 0.324144
# [200]	training's rmse: 0.240856	valid_1's rmse: 0.305776
# [300]	training's rmse: 0.192702	valid_1's rmse: 0.302686
# [400]	training's rmse: 0.158455	valid_1's rmse: 0.300973
# [500]	training's rmse: 0.133848	valid_1's rmse: 0.297212
# [600]	training's rmse: 0.114207	valid_1's rmse: 0.298174
# Early stopping, best iteration is:
# [537]	training's rmse: 0.126082	valid_1's rmse: 0.296768
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.324047	valid_1's rmse: 0.42917
# [200]	training's rmse: 0.243958	valid_1's rmse: 0.409538
# [300]	training's rmse: 0.19514	valid_1's rmse: 0.405044
# [400]	training's rmse: 0.16156	valid_1's rmse: 0.399671
# [500]	training's rmse: 0.136622	valid_1's rmse: 0.398159
# [600]	training's rmse: 0.117014	valid_1's rmse: 0.393093
# [700]	training's rmse: 0.101641	valid_1's rmse: 0.391762
# [800]	training's rmse: 0.0892539	valid_1's rmse: 0.391569
# Early stopping, best iteration is:
# [735]	training's rmse: 0.0972177	valid_1's rmse: 0.391188
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.323961	valid_1's rmse: 0.446671
# [200]	training's rmse: 0.244509	valid_1's rmse: 0.429186
# [300]	training's rmse: 0.198935	valid_1's rmse: 0.421161
# [400]	training's rmse: 0.166568	valid_1's rmse: 0.415415
# [500]	training's rmse: 0.141105	valid_1's rmse: 0.41163
# [600]	training's rmse: 0.121857	valid_1's rmse: 0.408885
# [700]	training's rmse: 0.106066	valid_1's rmse: 0.40763
# Early stopping, best iteration is:
# [684]	training's rmse: 0.108471	valid_1's rmse: 0.407071
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.331848	valid_1's rmse: 0.471305
# [200]	training's rmse: 0.253951	valid_1's rmse: 0.452482
# [300]	training's rmse: 0.207368	valid_1's rmse: 0.444716
# [400]	training's rmse: 0.175815	valid_1's rmse: 0.438327
# [500]	training's rmse: 0.150144	valid_1's rmse: 0.434607
# [600]	training's rmse: 0.129243	valid_1's rmse: 0.431704
# [700]	training's rmse: 0.112909	valid_1's rmse: 0.429958
# [800]	training's rmse: 0.0997348	valid_1's rmse: 0.429457
# [900]	training's rmse: 0.0880052	valid_1's rmse: 0.428605
# [1000]	training's rmse: 0.0781861	valid_1's rmse: 0.428799
# Early stopping, best iteration is:
# [905]	training's rmse: 0.0873931	valid_1's rmse: 0.428307
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.335534	valid_1's rmse: 0.397248
# [200]	training's rmse: 0.259104	valid_1's rmse: 0.380856
# [300]	training's rmse: 0.211752	valid_1's rmse: 0.367646
# [400]	training's rmse: 0.178754	valid_1's rmse: 0.362322
# [500]	training's rmse: 0.153113	valid_1's rmse: 0.35979
# [600]	training's rmse: 0.133545	valid_1's rmse: 0.357762
# [700]	training's rmse: 0.117223	valid_1's rmse: 0.356077
# [800]	training's rmse: 0.103705	valid_1's rmse: 0.354893
# [900]	training's rmse: 0.0921178	valid_1's rmse: 0.353222
# Early stopping, best iteration is:
# [883]	training's rmse: 0.0939673	valid_1's rmse: 0.352757
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.333831	valid_1's rmse: 0.377873
# [200]	training's rmse: 0.259561	valid_1's rmse: 0.358334
# [300]	training's rmse: 0.214837	valid_1's rmse: 0.350019
# [400]	training's rmse: 0.183612	valid_1's rmse: 0.347749
# [500]	training's rmse: 0.157809	valid_1's rmse: 0.34606
# [600]	training's rmse: 0.138124	valid_1's rmse: 0.345532
# [700]	training's rmse: 0.121765	valid_1's rmse: 0.345902
# Early stopping, best iteration is:
# [615]	training's rmse: 0.135848	valid_1's rmse: 0.345116
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.333193	valid_1's rmse: 0.414849
# [200]	training's rmse: 0.260381	valid_1's rmse: 0.392156
# [300]	training's rmse: 0.214851	valid_1's rmse: 0.383318
# [400]	training's rmse: 0.183313	valid_1's rmse: 0.376774
# [500]	training's rmse: 0.158649	valid_1's rmse: 0.375028
# [600]	training's rmse: 0.139126	valid_1's rmse: 0.373287
# [700]	training's rmse: 0.123858	valid_1's rmse: 0.372058
# [800]	training's rmse: 0.110722	valid_1's rmse: 0.372512
# Early stopping, best iteration is:
# [715]	training's rmse: 0.121664	valid_1's rmse: 0.371417
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.335495	valid_1's rmse: 0.359187
# [200]	training's rmse: 0.263767	valid_1's rmse: 0.333689
# [300]	training's rmse: 0.21994	valid_1's rmse: 0.322751
# [400]	training's rmse: 0.188205	valid_1's rmse: 0.316233
# [500]	training's rmse: 0.163493	valid_1's rmse: 0.314064
# [600]	training's rmse: 0.143566	valid_1's rmse: 0.309692
# [700]	training's rmse: 0.127979	valid_1's rmse: 0.308463
# [800]	training's rmse: 0.114331	valid_1's rmse: 0.307687
# [900]	training's rmse: 0.103024	valid_1's rmse: 0.307329
# [1000]	training's rmse: 0.0932044	valid_1's rmse: 0.306456
# [1100]	training's rmse: 0.0843566	valid_1's rmse: 0.304822
# [1200]	training's rmse: 0.0770279	valid_1's rmse: 0.304483
# [1300]	training's rmse: 0.0702093	valid_1's rmse: 0.30422
# [1400]	training's rmse: 0.0640885	valid_1's rmse: 0.30375
# [1500]	training's rmse: 0.0585903	valid_1's rmse: 0.303342
# [1600]	training's rmse: 0.0537595	valid_1's rmse: 0.303134
# [1700]	training's rmse: 0.0493699	valid_1's rmse: 0.302976
# [1800]	training's rmse: 0.0455863	valid_1's rmse: 0.303344
# Early stopping, best iteration is:
# [1707]	training's rmse: 0.0491243	valid_1's rmse: 0.302868

# %%
mse = mean_squared_error(train[target], oof)
print(f"OOF MSE: {mse:.6f}")
# Out:
# OOF MSE: 26574.031866

# %%
rmse = np.sqrt(mean_squared_error(train[target], oof))
print(f"OOF RMSE: {rmse:.6f}")
# Out:
# OOF RMSE: 163.015434
