# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.optimizers import Adam

# %%
tf.random.set_seed(2005)
np.random.seed(2005)

# %%
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# %%
X_train = X_train.astype('float32')
X_test  = X_test.astype('float32')

# %%
def plot_history(histories, title_suffix=''):
    plt.figure(figsize=(14, 5))

    plt.subplot(1, 2, 1)
    for label, history in histories.items():
        plt.plot(history.history['accuracy'], label=f'{label} - Train')
        plt.plot(history.history['val_accuracy'], '--', label=f'{label} - Test')
    plt.title(f'Accuracy {title_suffix}')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    for label, history in histories.items():
        plt.plot(history.history['loss'], label=f'{label} - Train')
        plt.plot(history.history['val_loss'], '--', label=f'{label} - Test')
    plt.title(f'Loss {title_suffix}')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.show()

# %%
histories_exp1 = {}

model1 = tf.keras.models.Sequential([
    tf.keras.layers.Input(shape=(28,28)),
    tf.keras.layers.Flatten(name="input"),
    tf.keras.layers.Dense(256, activation='relu', name="h_256"),
    tf.keras.layers.Dense(128, activation='relu', name="h_128"),
    tf.keras.layers.Dense(10, activation='softmax', name="output")
])

model1.compile(optimizer="adam",
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
histories_exp1[f'{20} эпох'] = (model1.fit(X_train, y_train,
                                           validation_data=(X_test, y_test),
                                           epochs=20))
# Out:
# Epoch 1/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7017 - loss: 6.5578 - val_accuracy: 0.7931 - val_loss: 0.5995
# Epoch 2/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8109 - loss: 0.5369 - val_accuracy: 0.7975 - val_loss: 0.5630
# Epoch 3/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8318 - loss: 0.4713 - val_accuracy: 0.8273 - val_loss: 0.4640
# Epoch 4/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8420 - loss: 0.4451 - val_accuracy: 0.8250 - val_loss: 0.4812
# Epoch 5/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8496 - loss: 0.4261 - val_accuracy: 0.8410 - val_loss: 0.4478
# Epoch 6/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8600 - loss: 0.3928 - val_accuracy: 0.8297 - val_loss: 0.4644
# Epoch 7/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8636 - loss: 0.3902 - val_accuracy: 0.8363 - val_loss: 0.4454
# Epoch 8/20
# ...

# %%
model10 = tf.keras.models.Sequential([
    tf.keras.layers.Input(shape=(28,28)),
    tf.keras.layers.Flatten(name="input"),
    tf.keras.layers.Dense(256, activation='relu', name="h_256"),
    tf.keras.layers.Dense(128, activation='relu', name="h_128"),
    tf.keras.layers.Dense(10, activation='softmax', name="output")
])

model10.compile(optimizer="adam",
               loss='sparse_categorical_crossentropy',
               metrics=['accuracy'])

# %%
histories_exp1[f'{100} эпох'] = (model10.fit(X_train, y_train,
                                             validation_data=(X_test, y_test),
                                             epochs=100))
# Out:
# Epoch 1/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7192 - loss: 7.1953 - val_accuracy: 0.7852 - val_loss: 0.6730
# Epoch 2/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8106 - loss: 0.5817 - val_accuracy: 0.7863 - val_loss: 0.6242
# Epoch 3/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8259 - loss: 0.5029 - val_accuracy: 0.7833 - val_loss: 0.6283
# Epoch 4/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8345 - loss: 0.4703 - val_accuracy: 0.7995 - val_loss: 0.5609
# Epoch 5/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8475 - loss: 0.4323 - val_accuracy: 0.8299 - val_loss: 0.4789
# Epoch 6/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8554 - loss: 0.3975 - val_accuracy: 0.8265 - val_loss: 0.4771
# Epoch 7/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8619 - loss: 0.3776 - val_accuracy: 0.8358 - val_loss: 0.4574
# Epoch 8/100
# ...

# %%
plot_history(histories_exp1)

# %%
histories_exp2 = {}

model2 = tf.keras.models.Sequential([
    tf.keras.layers.Input(shape=(28,28)),
    tf.keras.layers.Flatten(name="input"),
    tf.keras.layers.Dense(256, activation='relu', name="h_256"),
    tf.keras.layers.Dense(128, activation='relu', name="h_128"),
    tf.keras.layers.Dense(10, activation='softmax', name="output")
])

# %%
model2.compile(optimizer=Adam(learning_rate=0.0001),
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])

histories_exp2[f'lr=0.0001'] = (model2.fit(X_train, y_train,
                                               validation_data=(X_test, y_test),
                                               epochs=100))
# Out:
# Epoch 1/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6619 - loss: 13.9731 - val_accuracy: 0.7833 - val_loss: 2.1059
# Epoch 2/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7922 - loss: 1.6465 - val_accuracy: 0.7838 - val_loss: 1.3064
# Epoch 3/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8159 - loss: 0.9384 - val_accuracy: 0.8013 - val_loss: 0.9483
# Epoch 4/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8339 - loss: 0.6566 - val_accuracy: 0.8211 - val_loss: 0.7214
# Epoch 5/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8501 - loss: 0.5170 - val_accuracy: 0.8245 - val_loss: 0.6836
# Epoch 6/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8624 - loss: 0.4371 - val_accuracy: 0.8383 - val_loss: 0.5969
# Epoch 7/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8735 - loss: 0.3782 - val_accuracy: 0.8398 - val_loss: 0.5562
# Epoch 8/100
# ...

# %%
model2.compile(optimizer=Adam(learning_rate=0.01),
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])

histories_exp2[f'lr=0.01'] = (model2.fit(X_train, y_train,
                                            validation_data=(X_test, y_test),
                                            epochs=100))
# Out:
# Epoch 1/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 26s 14ms/step - accuracy: 0.1982 - loss: 8.3645 - val_accuracy: 0.1002 - val_loss: 2.3042
# Epoch 2/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.0981 - loss: 2.3038 - val_accuracy: 0.1003 - val_loss: 2.3040
# Epoch 3/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.0989 - loss: 2.3854 - val_accuracy: 0.1000 - val_loss: 2.3047
# Epoch 4/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.0988 - loss: 2.3042 - val_accuracy: 0.1000 - val_loss: 2.3047
# Epoch 5/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.0984 - loss: 2.3041 - val_accuracy: 0.1000 - val_loss: 2.3047
# Epoch 6/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.0984 - loss: 2.3041 - val_accuracy: 0.1000 - val_loss: 2.3047
# Epoch 7/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.0984 - loss: 2.3041 - val_accuracy: 0.1000 - val_loss: 2.3047
# Epoch 8/100
# ...

# %%
plot_history(histories_exp2)

# %%
histories_exp3 = {}

# %%
model4 = tf.keras.models.Sequential([
    tf.keras.layers.Input(shape=(28,28)),
    tf.keras.layers.Flatten(name="input"),
    tf.keras.layers.Dense(256, activation='relu', name="h_256"),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(128, activation='relu', name="h_128"),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation='softmax', name="output")
])

model4.compile(optimizer="adam",
               loss='sparse_categorical_crossentropy',
               metrics=['accuracy'])


histories_exp3[f'C dropout'] = (model4.fit(X_train, y_train,
                                         validation_data=(X_test, y_test),
                                         epochs=100))
# Out:
# Epoch 1/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.4998 - loss: 8.0534 - val_accuracy: 0.6876 - val_loss: 0.7869
# Epoch 2/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.6485 - loss: 0.9424 - val_accuracy: 0.6998 - val_loss: 0.6775
# Epoch 3/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.6826 - loss: 0.8118 - val_accuracy: 0.7174 - val_loss: 0.6596
# Epoch 4/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7095 - loss: 0.7733 - val_accuracy: 0.7728 - val_loss: 0.5892
# Epoch 5/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7304 - loss: 0.7037 - val_accuracy: 0.7802 - val_loss: 0.5762
# Epoch 6/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7430 - loss: 0.7013 - val_accuracy: 0.7704 - val_loss: 0.6006
# Epoch 7/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7564 - loss: 0.6563 - val_accuracy: 0.8089 - val_loss: 0.5010
# Epoch 8/100
# ...

# %%
model5 = tf.keras.models.Sequential([
    tf.keras.layers.Input(shape=(28,28)),
    tf.keras.layers.Flatten(name="input"),
    tf.keras.layers.Dense(256, activation='relu', name="h_256"),
    tf.keras.layers.Dense(128, activation='relu', name="h_128"),
    tf.keras.layers.Dense(10, activation='softmax', name="output")
])

model5.compile(optimizer="adam",
               loss='sparse_categorical_crossentropy',
               metrics=['accuracy'])

histories_exp3[f'Без dropout'] = (model5.fit(X_train, y_train,
                                           validation_data=(X_test, y_test),
                                           epochs=100))
# Out:
# Epoch 1/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7181 - loss: 7.6422 - val_accuracy: 0.7670 - val_loss: 0.7508
# Epoch 2/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8113 - loss: 0.5709 - val_accuracy: 0.7952 - val_loss: 0.6259
# Epoch 3/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8334 - loss: 0.4807 - val_accuracy: 0.8040 - val_loss: 0.5874
# Epoch 4/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8408 - loss: 0.4509 - val_accuracy: 0.8218 - val_loss: 0.5057
# Epoch 5/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8528 - loss: 0.4139 - val_accuracy: 0.8273 - val_loss: 0.4738
# Epoch 6/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8588 - loss: 0.3952 - val_accuracy: 0.8424 - val_loss: 0.4423
# Epoch 7/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8680 - loss: 0.3722 - val_accuracy: 0.8427 - val_loss: 0.4482
# Epoch 8/100
# ...

# %%
plot_history(histories_exp3)

# %%
histories_exp4 = {}

# %%
model6 = tf.keras.models.Sequential([
    tf.keras.layers.Input(shape=(28, 28)),
    tf.keras.layers.Flatten(name="input"),
    tf.keras.layers.Dense(256, activation='relu', name="h_256"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(128, activation='relu', name="h_128"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(10, activation='softmax', name="output")
])

model6.compile(optimizer="adam",
               loss='sparse_categorical_crossentropy',
               metrics=['accuracy'])

histories_exp4[f'С batch_normalization'] = (model6.fit(X_train, y_train,
                                             validation_data=(X_test, y_test),
                                             epochs=100))
# Out:
# Epoch 1/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7962 - loss: 0.5784 - val_accuracy: 0.8350 - val_loss: 0.5286
# Epoch 2/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8566 - loss: 0.3932 - val_accuracy: 0.8424 - val_loss: 0.5026
# Epoch 3/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8719 - loss: 0.3492 - val_accuracy: 0.8430 - val_loss: 0.5073
# Epoch 4/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8814 - loss: 0.3219 - val_accuracy: 0.8275 - val_loss: 0.5185
# Epoch 5/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8872 - loss: 0.3023 - val_accuracy: 0.8422 - val_loss: 0.5855
# Epoch 6/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8937 - loss: 0.2842 - val_accuracy: 0.8551 - val_loss: 0.6852
# Epoch 7/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8990 - loss: 0.2726 - val_accuracy: 0.7503 - val_loss: 1.0742
# Epoch 8/100
# ...

# %%
model7 = tf.keras.models.Sequential([
    tf.keras.layers.Input(shape=(28, 28)),
    tf.keras.layers.Flatten(name="input"),
    tf.keras.layers.Dense(256, activation='relu', name="h_256"),
    tf.keras.layers.Dense(128, activation='relu', name="h_128"),
    tf.keras.layers.Dense(10, activation='softmax', name="output")
])

model7.compile(optimizer="adam",
               loss='sparse_categorical_crossentropy',
               metrics=['accuracy'])

histories_exp4[f'Без batch_normalization'] = (model7.fit(X_train, y_train,
                                                       validation_data=(X_test, y_test),
                                                       epochs=100))
# Out:
# Epoch 1/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7181 - loss: 7.0492 - val_accuracy: 0.7631 - val_loss: 0.7614
# Epoch 2/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8037 - loss: 0.5992 - val_accuracy: 0.7574 - val_loss: 0.6560
# Epoch 3/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8252 - loss: 0.5061 - val_accuracy: 0.8303 - val_loss: 0.4941
# Epoch 4/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8367 - loss: 0.4666 - val_accuracy: 0.7981 - val_loss: 0.5398
# Epoch 5/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8463 - loss: 0.4314 - val_accuracy: 0.8198 - val_loss: 0.5078
# Epoch 6/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8563 - loss: 0.3953 - val_accuracy: 0.8313 - val_loss: 0.4619
# Epoch 7/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8600 - loss: 0.3877 - val_accuracy: 0.8305 - val_loss: 0.4577
# Epoch 8/100
# ...

# %%
plot_history(histories_exp4)
